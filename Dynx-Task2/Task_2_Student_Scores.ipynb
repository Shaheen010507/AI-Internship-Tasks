# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("student_scores.csv")

# Display first 10 rows
print("First 10 Rows:")
print(df.head(10))

# Filter students who studied more than 6 hours
filtered_df = df[df["Hours_Studied"] > 6]

print("\nStudents who studied more than 6 hours:")
print(filtered_df)

# Basic information
print("\nDataset Information:")
print(df.describe())

# Visualization
plt.figure(figsize=(8,5))
plt.scatter(df["Hours_Studied"], df["Exam_Score"])

plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Hours Studied vs Exam Score")

plt.show()
# Out:
# First 10 Rows:
#    Hours_Studied  Exam_Score
# 0           5.94       21.17
# 1           7.44       46.95
# 2           6.42       29.55
# 3           5.90       27.31
# 4           4.81       17.79
# 5           6.81       37.94
# 6           4.94       16.63
# 7           9.03       44.09
# 8           9.67       43.87
# 9           4.45       24.18
#
# Students who studied more than 6 hours:
#     Hours_Studied  Exam_Score
# 1            7.44       46.95
# 2            6.42       29.55
# 5            6.81       37.94
# 7            9.03       44.09
# 8            9.67       43.87
# 10           8.13       38.10
# 12           6.11       30.41
# 13           9.33       48.79
# 17           8.49       40.64
# 18           8.00       36.64
# 19           8.83       42.35
# 20           9.81       44.98
# 21           8.19       32.32
# 23           8.02       38.09
# 25           6.76       36.11
# 27           9.50       47.76
# 31           7.97       33.68
# 33           6.12       27.18
# 35           6.56       29.91
# 36           6.51       30.99
# 37           6.55       33.03
# 38           9.49       41.62
# 39           7.14       40.20
# 42           7.28       43.84
# 44           7.00       40.89
# 45           7.04       34.30
#
# Dataset Information:
#        Hours_Studied  Exam_Score
# count       50.00000   50.000000
# mean         5.84120   28.343400
# std          2.47562   12.836373
# min          1.17000    1.500000
# 25%          4.31500   18.635000
# 50%          6.11500   29.730000
# 75%          7.83750   38.097500
# max          9.81000   48.790000
